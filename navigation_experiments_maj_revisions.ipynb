# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_a_bottle_of_beer()
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 11397.97it/s]
# Loading : train[55]
# A simple question!
#
# I would recommend searching in the **Kitchen** (option 2).
#
# Justification: The kitchen is typically where beverages, including beer, are stored and consumed. It's a common place to find a fridge or beer cooler, which would likely contain a bottle of beer.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.GEMMA)
path = spp.bring_me_hair_pin()
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_GEMMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 12352.76it/s]
# Loading : train[55]
# **3. Bedroom**
#
# ...

# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_4b)
path, _, _ = spp.bring_me_this("TV remote control")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_MISTRAL_4b/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 11265.05it/s]
# Loading : train[55]
# ...

# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_4b)
path, _, _ = spp.bring_me_this("toothbrush")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_llama/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|█████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8371.83it/s]
# Loading : train[55]
# Based on the context of searching for a "toothbrush", I would recommend looking in the **Bathroom** (option 4) first.
#
# ...

# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_4b)
path, _, _ = spp.bring_me_this("pillow")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_llama/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9328.30it/s]
# Loading : train[55]
# Based on the item you're looking for, "pillow", I would recommend searching in:
#
# **3. Bedroom**
#
# ...

# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_4b)
path, _, _ = spp.bring_me_this("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_llama/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8937.69it/s]
# Loading : train[55]
# I'd recommend searching the **Kitchen** (option 2) first.
#
# Here's my reasoning:
#
# * A kitchen is often a hub for daily activities, and people tend to use credit cards for various transactions, such as online shopping or paying bills.
# ...

# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_6b)
path, _, _ = spp.bring_me_this("comfy pyjamas")
spp.visualise_path(path)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Loaded : experiment_data/pkl_llama/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8608.80it/s]
# Loading : train[55]
# A cozy question!
#
# I would recommend looking in the **Bedroom** (option 3) first.
#
# ...

# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_6b)
path, _, _ = spp.bring_me_this("car keys")
spp.visualise_path(path)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Loaded : experiment_data/pkl_llama/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8574.78it/s]
# Loading : train[55]
# A common problem!
#
# I would recommend searching the **Bedroom** (option 3) first.
#
# Here's my reasoning:
#
# ...

# %%
from llm_room_classifier import LLMRoomClassifier, LLMType
from semantic_path_planner import SemanticPathPlanner

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_6b)
path = spp.bring_me_a_bottle_of_beer_from_actual_objs()
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_MISTRAL_6b/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 12007.53it/s]
# Loading : train[55]
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("pillow")
spp.visualise_path(path)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9109.14it/s]
# Loading : train[55]
# Based on the object you're searching for, which is a "pillow", I would recommend looking in the **Bedroom** (option 3) first.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("hair pin")
spp.visualise_path(path)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8856.40it/s]
# Loading : train[55]
# A great question!
#
# Based on the information provided, I would suggest looking in **room 3: Bedroom** first.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("TV remote control")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 5509.04it/s]
# Loading : train[55]
# A simple but important question!
#
# I would recommend searching the **Living Room** (option 1) first.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8016.28it/s]
# Loading : train[55]
# Based on the information provided, I would recommend searching in the "Bedroom" (Option 3) first.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("comfy pyjamas")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8875.41it/s]
# Loading : train[55]
# I'd recommend searching for comfy pyjamas in the **Bedroom** (option 3).
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("car keys")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9062.46it/s]
# Loading : train[55]
# Based on the context, I would recommend looking in the "Bedroom" (option 3) first.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9508.95it/s]
# Loading : train[55]
# Based on the information provided, I would suggest searching in the "Bedroom" (option 3) first.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9345.97it/s]
# Loading : train[55]
# Based on the information provided, I would recommend searching for a credit card in the "Living room" (option 1).
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.LLAMA)
path, _, _ = spp.bring_me_this_from_actual_objs("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9296.48it/s]
# Loading : train[55]
# A simple question!
#
# I would recommend searching in the **Kitchen** (option 2) as credit cards are often kept with wallets or pouches that can be found in a kitchen drawer or on a counter.
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.GEMMA)
path, _, _ = spp.bring_me_this_from_actual_objs("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_GEMMA/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9567.12it/s]
# Loading : train[55]
# **3. Bedroom**
#
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_6b)
path, _, _ = spp.bring_me_this_from_actual_objs("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_MISTRAL_6b/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8832.14it/s]
# Loading : train[55]
# ...

# %%
from semantic_path_planner import SemanticPathPlanner
from llm_room_classifier import LLMType

spp = SemanticPathPlanner("train_55", LLMType.MISTRAL_4b)
path, _, _ = spp.bring_me_this_from_actual_objs("credit card")
spp.visualise_path(path)
# Out:
# Loaded : experiment_data/pkl_MISTRAL_4b/scene_descr_train_55.pkl scene
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9347.16it/s]
# Loading : train[55]
#  Based on the information you have provided, it seems that you are asking for a credit card rather than looking for an item in a specific room. Therefore, the answer to your question about which room to look in first does not apply in this context.
#
# ...
