# %%
from semantic_mapper import SemanticMapper
from llm_room_classifier import LLMType
from room_type import RoomType

sm = SemanticMapper("train_55", LLMType.LLAMA)
img = sm.get_top_down_frame()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 8911.01it/s]
# Loading val: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9150.24it/s]
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9035.77it/s]
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# Loading : train[55]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
from room_type import RoomType
for i in range(0, 360, 45):
    print(i)

(271 in range(0, 360, 45))

print(RoomType.BEDROOM.colour_of_room(RoomType.BEDROOM))
print(RoomType.colour_of_room(RoomType.KITCHEN))
# Out:
# 0
# 45
# 90
# 135
# 180
# 225
# 270
# 315
# #00008F
# #008F00

# %%
from room_type import RoomType
import matplotlib.pyplot as plt

def find_observed_point_by_pose(pose, room_points):
    #(pos, rot) = pose # ((10.75, 1.57599937915802, 1.0), (30.000003814697266, 0.0, 0))
    result = None
    for rp in room_points:
        if rp['point_pose'] == pose:
            result = rp
            return result
    return result

##
# Extract all rotations with the given XY position in all room points.
# It also extracts the classified result and sorts the extracted rotations.
##
def get_all_rotations_of_xy_pose(xy_pose, room_points):
    result = []
    for rp in room_points: # go through all points
        if rp['point_pose'][0] == xy_pose:
            result.append((int(rp['point_pose'][1][1]), rp["room_type_llm"])) # and extract yaw rotations along with classification result from the required XY position

    result = pad_missing_rotations(result)
    
    result = sorted(result, key=lambda x: x[0], reverse=True) # sort the result by yaw rotation angle
    return result

##
# Some rotations will not be classified because the object list at that pose contained only common objects or was empty.
# The classifications will be missing, so let's fill them back in.
##
def pad_missing_rotations(classified_rotations):
    padded_classified_rotations = []
    pad_needed = False
    
    for i in range(0, 360, 45): # there should be degrees of 0, 45, 90, 135, 180, 225, 270, 315. If there ain't, then we pad
        pad_needed = True
        for cr in classified_rotations:
            if cr[0] == i: # if rotation found, then skip the rest
                pad_needed = False
                padded_classified_rotations.append(cr)
                break
        if (pad_needed): # if rotation was not found, then we need to inject it
            padded_classified_rotations.append((i, RoomType.NOT_CLASSIFIED))
            
    return padded_classified_rotations

processed_xy_poses = []

def plot_semantic_position(sorted_classified_rotations):
    segment_size = 100.0/8.0
    colors = []

    for rtn in sorted_classified_rotations:
        print(rtn[1])
        print(rtn[1] == RoomType.BEDROOM)
        colors.append(RoomType.colour_of_room(rtn[1]))
    
    y = [segment_size, segment_size, segment_size, segment_size, segment_size, segment_size, segment_size, segment_size]
    plt.pie(y, colors=colors, radius=0.1)
    plt.show()

# Go through all of the room points and process all rotations for each point
room_points = sm.scene_description.get_all_points()
classified_pose_rtns_pairs = []

for rp in room_points:
    (current_xy, current_rot) = rp['point_pose'] # get current XY position
    if (current_xy in processed_xy_poses): continue
    print(rp['point_pose'][0])
    classified_rotations = get_all_rotations_of_xy_pose(current_xy, room_points)
    print(classified_rotations) # get all rotations for the given XY position
    plot_semantic_position(classified_rotations)
    processed_xy_poses.append(current_xy) # append the XY position to the collection of positions that we don't want to see anymore
    classified_pose_rtns_pairs.append((current_xy, classified_rotations))
# Out:
# (4.0, 1.57599937915802, 9.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.LIVING_ROOM: 1>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# (6.25, 1.57599937915802, 13.75)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.LIVING_ROOM: 1>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.BATHROOM: 4>), (135, <RoomType.BATHROOM: 4>), (90, <RoomType.BATHROOM: 4>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.KITCHEN: 2>)]
# RoomType.BEDROOM
# True
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.BATHROOM
# False
# RoomType.BATHROOM
# False
# RoomType.BATHROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# (4.25, 1.57599937915802, 13.75)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.KITCHEN: 2>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.KITCHEN
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# (0.25, 1.57599937915802, 6.25)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.LIVING_ROOM: 1>), (135, <RoomType.LIVING_ROOM: 1>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (4.5, 1.57599937915802, 5.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.KITCHEN: 2>), (225, <RoomType.KITCHEN: 2>), (180, <RoomType.KITCHEN: 2>), (135, <RoomType.KITCHEN: 2>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (14.25, 1.57599937915802, 2.0)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# (7.75, 1.57599937915802, 4.25)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# (2.25, 1.57599937915802, 12.0)
# [(315, <RoomType.LIVING_ROOM: 1>), (270, <RoomType.LIVING_ROOM: 1>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.KITCHEN: 2>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.LIVING_ROOM: 1>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.KITCHEN
# False
# RoomType.BEDROOM
# True
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# (1.25, 1.57599937915802, 10.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.LIVING_ROOM: 1>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# (7.25, 1.57599937915802, 12.5)
# [(315, <RoomType.BATHROOM: 4>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.BATHROOM: 4>), (90, <RoomType.BATHROOM: 4>), (45, <RoomType.BATHROOM: 4>), (0, <RoomType.BATHROOM: 4>)]
# RoomType.BATHROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BATHROOM
# False
# RoomType.BATHROOM
# False
# RoomType.BATHROOM
# False
# RoomType.BATHROOM
# False
# (9.5, 1.57599937915802, 3.75)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.LIVING_ROOM: 1>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# (6.5, 1.57599937915802, 10.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.LIVING_ROOM: 1>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (8.25, 1.57599937915802, 3.0)
# [(315, <RoomType.KITCHEN: 2>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.KITCHEN: 2>)]
# RoomType.KITCHEN
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# (11.25, 1.57599937915802, 5.25)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# (13.75, 1.57599937915802, 4.5)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# (11.75, 1.57599937915802, 10.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.LIVING_ROOM: 1>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (8.5, 1.57599937915802, 10.5)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.LIVING_ROOM: 1>), (135, <RoomType.LIVING_ROOM: 1>), (90, <RoomType.LIVING_ROOM: 1>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (2.5, 1.57599937915802, 6.75)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# (5.25, 1.57599937915802, 10.25)
# [(315, <RoomType.KITCHEN: 2>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.LIVING_ROOM: 1>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.LIVING_ROOM: 1>)]
# RoomType.KITCHEN
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# (10.25, 1.57599937915802, 6.5)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# (2.25, 1.57599937915802, 5.0)
# [(315, <RoomType.LIVING_ROOM: 1>), (270, <RoomType.KITCHEN: 2>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.KITCHEN: 2>), (135, <RoomType.KITCHEN: 2>), (90, <RoomType.LIVING_ROOM: 1>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.LIVING_ROOM
# False
# RoomType.KITCHEN
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (12.25, 1.57599937915802, 3.25)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.LIVING_ROOM: 1>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# (1.75, 1.57599937915802, 8.75)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.LIVING_ROOM: 1>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.LIVING_ROOM: 1>), (0, <RoomType.LIVING_ROOM: 1>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# (12.5, 1.57599937915802, 4.5)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.LIVING_ROOM: 1>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# (6.25, 1.57599937915802, 5.5)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.KITCHEN: 2>), (180, <RoomType.KITCHEN: 2>), (135, <RoomType.KITCHEN: 2>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.LIVING_ROOM: 1>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# (12.5, 1.57599937915802, 1.75)
# [(315, <RoomType.LIVING_ROOM: 1>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.LIVING_ROOM
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# (3.75, 1.57599937915802, 11.5)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.KITCHEN: 2>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.LIVING_ROOM: 1>), (0, <RoomType.LIVING_ROOM: 1>)]
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# (4.5, 1.57599937915802, 3.5)
# [(315, <RoomType.LIVING_ROOM: 1>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.KITCHEN: 2>), (180, <RoomType.KITCHEN: 2>), (135, <RoomType.KITCHEN: 2>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# (9.75, 1.57599937915802, 9.25)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# (11.75, 1.57599937915802, 6.5)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (11.0, 1.57599937915802, 9.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.LIVING_ROOM: 1>), (180, <RoomType.LIVING_ROOM: 1>), (135, <RoomType.LIVING_ROOM: 1>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (1.0, 1.57599937915802, 4.0)
# [(315, <RoomType.LIVING_ROOM: 1>), (270, <RoomType.LIVING_ROOM: 1>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.KITCHEN: 2>), (135, <RoomType.KITCHEN: 2>), (90, <RoomType.KITCHEN: 2>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.LIVING_ROOM
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.KITCHEN
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (10.5, 1.57599937915802, 3.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.LIVING_ROOM: 1>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# (13.0, 1.57599937915802, 9.0)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.BEDROOM: 3>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.BEDROOM: 3>), (45, <RoomType.BEDROOM: 3>), (0, <RoomType.BEDROOM: 3>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# (5.75, 1.57599937915802, 8.5)
# [(315, <RoomType.BEDROOM: 3>), (270, <RoomType.BEDROOM: 3>), (225, <RoomType.BEDROOM: 3>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.NOT_CLASSIFIED: 6>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.LIVING_ROOM: 1>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.LIVING_ROOM
# False
# RoomType.NOT_CLASSIFIED
# False
# (6.0, 1.57599937915802, 6.75)
# [(315, <RoomType.NOT_CLASSIFIED: 6>), (270, <RoomType.NOT_CLASSIFIED: 6>), (225, <RoomType.NOT_CLASSIFIED: 6>), (180, <RoomType.NOT_CLASSIFIED: 6>), (135, <RoomType.BEDROOM: 3>), (90, <RoomType.NOT_CLASSIFIED: 6>), (45, <RoomType.NOT_CLASSIFIED: 6>), (0, <RoomType.NOT_CLASSIFIED: 6>)]
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.BEDROOM
# True
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False
# RoomType.NOT_CLASSIFIED
# False

# %%
from thortils.agent import thor_reachable_positions, thor_agent_position, thor_agent_pose
from thortils.utils import roundany

def plot_pie(pos_rtn, ax):
    ax.pie(x[['a','b','c']], center=(x['lat'],x['lon']), radius=1,colors=['r', 'b', 'g'], wedgeprops={'clip_on':True}, frame=False)

def plot_semantic_position(position, sorted_classified_rotations, ax):
    segment_size = 100.0/8.0
    colors = []

    for rtn in sorted_classified_rotations:
        print(rtn)
        colors.append(RoomType.colour_of_room(rtn[1]))
    
    y = [segment_size, segment_size, segment_size, segment_size, segment_size, segment_size, segment_size, segment_size]
    #plt.pie(y, colors=colors, radius=0.1)
    ax.pie(y, center=(position[0],position[2]), radius=0.7,colors=colors, wedgeprops={'clip_on':True}, frame=False, startangle = (90 - 100.0/8.0))
    #plt.show()

##
# Plot a path on the top-down view of the habitat
##
def visualise_map(self, classified_positions):
    #grid_size = self.controller.initialization_parameters["gridSize"]
    grid_size = sm.controller.initialization_parameters["gridSize"]

    reachable_positions = [
        tuple(map(lambda x: roundany(x, grid_size), pos))
        #for pos in thor_reachable_positions(self.controller)]
        for pos in thor_reachable_positions(sm.controller)]

    x_max = max([pos[0] for pos in reachable_positions])
    z_max = max([pos[1] for pos in reachable_positions])
    x_min = min([pos[0] for pos in reachable_positions])
    z_min = min([pos[1] for pos in reachable_positions])

    fig, ax = plt.subplots()

    # another way how to plot the path
    #x = [p[0]["x"] for p in path]
    #z = [p[0]["z"] for p in path]
    #ax.scatter(x, z, s=300, c='gray', zorder=1)

    # setting up for the top-down picture of the habitat
    print(str(x_min-grid_size) + " " + str(x_max+grid_size) + " " + str(z_min-grid_size) + " " + str(z_max+grid_size))
    #img = self.get_top_down_frame()
    img = sm.get_top_down_frame()
    ex_mul = 7
    ax.imshow(img, extent=[x_min-ex_mul*grid_size, x_max+ex_mul*grid_size, z_min-ex_mul*grid_size, z_max+ex_mul*grid_size])

    # set up for the path print
    lim_mul = 4
    ax.set_xlim(x_min-lim_mul*grid_size, x_max+lim_mul*grid_size)
    ax.set_ylim(z_min-lim_mul*grid_size, z_max+lim_mul*grid_size)

    # map
    #for pos_rtns in classified_positions:
    #    x = pos_rtns[0][0]
    #    z = pos_rtns[0][2]
    #    ax.scatter([x], [z], s=30, zorder=2, c="blue")
    #    #plot_semantic_position(pos_rtns[0], pos_rtns[1], ax)

    y_init = ax.get_ylim()
    x_init = ax.get_xlim()

    i = 0
    # map
    for pos_rtns in classified_positions:
        x = pos_rtns[0][0]
        z = pos_rtns[0][2]
        #ax.scatter([x], [z], s=30, zorder=2, c="blue")
        plot_semantic_position(pos_rtns[0], pos_rtns[1], ax)
        i+=1
        #if i == 3: break

    ax.set_ylim(y_init)
    ax.set_xlim(x_init)
    
    plt.axis('off')
    plt.show()

visualise_map(None, classified_pose_rtns_pairs)
# Out:
# 0.0 14.5 0.0 14.5
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.LIVING_ROOM: 1>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.LIVING_ROOM: 1>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.BATHROOM: 4>)
# (135, <RoomType.BATHROOM: 4>)
# (90, <RoomType.BATHROOM: 4>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.KITCHEN: 2>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.KITCHEN: 2>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.LIVING_ROOM: 1>)
# (135, <RoomType.LIVING_ROOM: 1>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.KITCHEN: 2>)
# (225, <RoomType.KITCHEN: 2>)
# (180, <RoomType.KITCHEN: 2>)
# (135, <RoomType.KITCHEN: 2>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.LIVING_ROOM: 1>)
# (270, <RoomType.LIVING_ROOM: 1>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.KITCHEN: 2>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.LIVING_ROOM: 1>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.LIVING_ROOM: 1>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.BATHROOM: 4>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.BATHROOM: 4>)
# (90, <RoomType.BATHROOM: 4>)
# (45, <RoomType.BATHROOM: 4>)
# (0, <RoomType.BATHROOM: 4>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.LIVING_ROOM: 1>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.LIVING_ROOM: 1>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.KITCHEN: 2>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.KITCHEN: 2>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.LIVING_ROOM: 1>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.LIVING_ROOM: 1>)
# (135, <RoomType.LIVING_ROOM: 1>)
# (90, <RoomType.LIVING_ROOM: 1>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.KITCHEN: 2>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.LIVING_ROOM: 1>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.LIVING_ROOM: 1>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.LIVING_ROOM: 1>)
# (270, <RoomType.KITCHEN: 2>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.KITCHEN: 2>)
# (135, <RoomType.KITCHEN: 2>)
# (90, <RoomType.LIVING_ROOM: 1>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.LIVING_ROOM: 1>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.LIVING_ROOM: 1>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.LIVING_ROOM: 1>)
# (0, <RoomType.LIVING_ROOM: 1>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.LIVING_ROOM: 1>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.KITCHEN: 2>)
# (180, <RoomType.KITCHEN: 2>)
# (135, <RoomType.KITCHEN: 2>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.LIVING_ROOM: 1>)
# (315, <RoomType.LIVING_ROOM: 1>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.KITCHEN: 2>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.LIVING_ROOM: 1>)
# (0, <RoomType.LIVING_ROOM: 1>)
# (315, <RoomType.LIVING_ROOM: 1>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.KITCHEN: 2>)
# (180, <RoomType.KITCHEN: 2>)
# (135, <RoomType.KITCHEN: 2>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.LIVING_ROOM: 1>)
# (180, <RoomType.LIVING_ROOM: 1>)
# (135, <RoomType.LIVING_ROOM: 1>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.LIVING_ROOM: 1>)
# (270, <RoomType.LIVING_ROOM: 1>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.KITCHEN: 2>)
# (135, <RoomType.KITCHEN: 2>)
# (90, <RoomType.KITCHEN: 2>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.LIVING_ROOM: 1>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.BEDROOM: 3>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.BEDROOM: 3>)
# (45, <RoomType.BEDROOM: 3>)
# (0, <RoomType.BEDROOM: 3>)
# (315, <RoomType.BEDROOM: 3>)
# (270, <RoomType.BEDROOM: 3>)
# (225, <RoomType.BEDROOM: 3>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.NOT_CLASSIFIED: 6>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.LIVING_ROOM: 1>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)
# (315, <RoomType.NOT_CLASSIFIED: 6>)
# (270, <RoomType.NOT_CLASSIFIED: 6>)
# (225, <RoomType.NOT_CLASSIFIED: 6>)
# (180, <RoomType.NOT_CLASSIFIED: 6>)
# (135, <RoomType.BEDROOM: 3>)
# (90, <RoomType.NOT_CLASSIFIED: 6>)
# (45, <RoomType.NOT_CLASSIFIED: 6>)
# (0, <RoomType.NOT_CLASSIFIED: 6>)

# %%
    from scene_description import ClassifierType

    ##
    # Extract all rotations with the given XY position in all room points.
    # It also extracts the classified result and sorts the extracted rotations.
    ##
    def get_all_rotations_of_xy_pose(xy_pose, room_points):
        result = []
        room_points = sm.scene_description.get_all_points()
        for rp in room_points: # go through all points
            if rp['point_pose'][0] == xy_pose:
                result.append((int(rp['point_pose'][1][1]), rp["room_type_llm"])) # and extract yaw rotations along with classification result from the required XY position

        result = pad_missing_rotations(result)

        result = sorted(result, key=lambda x: x[0], reverse=True) # sort the result by yaw rotation angle, but we need id reversed because of the way pie plotting works
        return result

    ##
    # Some rotations will not be classified because the object list at that pose contained only common objects or was empty.
    # The classifications will be missing, so let's fill them back in.
    ##
    def pad_missing_rotations(classified_rotations):
        padded_classified_rotations = []
        pad_needed = False

        for i in range(0, 360, 45): # there should be degrees of 0, 45, 90, 135, 180, 225, 270, 315. If there ain't, then we pad
            pad_needed = True
            for cr in classified_rotations:
                if cr[0] == i: # if rotation found, then skip the rest
                    pad_needed = False
                    padded_classified_rotations.append(cr)
                    break
            if (pad_needed): # if rotation was not found, then we need to inject it
                padded_classified_rotations.append((i, RoomType.NOT_CLASSIFIED))

        return padded_classified_rotations

    ##
    # Go through all of the room points and process all rotations for each point
    # making it ready to plot on the top down frame. This will return
    # classified_pose_rtns_pairs, which will be used in other functions.
    ##
    def prepare_classified_poses_for_processing():
        room_points = sm.scene_description.get_all_points()
        classified_pose_rtns_pairs = []
        processed_xy_poses = []

        # Go through all of the room points and process all rotations for each point
        for rp in room_points:
            (current_xy, current_rot) = rp['point_pose'] # get current XY position
            if (current_xy in processed_xy_poses): continue
            #print(rp['point_pose'][0])
            classified_rotations = get_all_rotations_of_xy_pose(current_xy, room_points)
            #print(classified_rotations) # get all rotations for the given XY position
            #self.plot_semantic_position(classified_rotations)
            processed_xy_poses.append(current_xy) # append the XY position to the collection of positions that we don't want to see anymore
            classified_pose_rtns_pairs.append((current_xy, classified_rotations, rp["room_type_gt"]))

        return classified_pose_rtns_pairs

    ##
    # Create the pie plot of a semantic position with all the segments coloured
    # according to the classifictation.
    ##
    def plot_semantic_position(position, sorted_classified_rotations, ax):
        segment_size = 100.0/8.0 # we have 8 directions of view and 100% to cover
        colors = []

        # assemble the colours for the observed classifications
        for rtn in sorted_classified_rotations:
            #print(rtn)
            colors.append(RoomType.colour_of_room(rtn[1]))

        # all pie segments will be of the same size, just different colours
        y = [segment_size, segment_size, segment_size, segment_size, segment_size, segment_size, segment_size, segment_size]
        #plt.pie(y, colors=colors, radius=0.1)
        ax.pie(y, center=(position[0],position[2]), radius=0.7,colors=colors, wedgeprops={'clip_on':True}, frame=False, startangle = (90 - (360.0/8.0)/2.0))
        #plt.show()

    ##
    # Plot a path on the top-down view of the habitat
    ##
    def visualise_map(classified_positions, show_directions=True):
        #grid_size = self.controller.initialization_parameters["gridSize"]
        grid_size = sm.controller.initialization_parameters["gridSize"]

        reachable_positions = [
            tuple(map(lambda x: roundany(x, grid_size), pos))
            #for pos in thor_reachable_positions(self.controller)]
            for pos in thor_reachable_positions(sm.controller)]

        x_max = max([pos[0] for pos in reachable_positions])
        z_max = max([pos[1] for pos in reachable_positions])
        x_min = min([pos[0] for pos in reachable_positions])
        z_min = min([pos[1] for pos in reachable_positions])

        fig, ax = plt.subplots()

        # another way how to plot the path
        #x = [p[0]["x"] for p in path]
        #z = [p[0]["z"] for p in path]
        #ax.scatter(x, z, s=300, c='gray', zorder=1)

        # setting up for the top-down picture of the habitat
        #print(str(x_min-grid_size) + " " + str(x_max+grid_size) + " " + str(z_min-grid_size) + " " + str(z_max+grid_size))
        #img = self.get_top_down_frame()
        img = sm.get_top_down_frame()
        ex_mul = 7
        ax.imshow(img, extent=[x_min-ex_mul*grid_size, x_max+ex_mul*grid_size, z_min-ex_mul*grid_size, z_max+ex_mul*grid_size])

        # set up for the path print
        lim_mul = 4
        ax.set_xlim(x_min-lim_mul*grid_size, x_max+lim_mul*grid_size)
        ax.set_ylim(z_min-lim_mul*grid_size, z_max+lim_mul*grid_size)

        if show_directions:
            y_init = ax.get_ylim()
            x_init = ax.get_xlim()

            i = 0
            # map
            for pos_rtns in classified_positions:
                x = pos_rtns[0][0]
                z = pos_rtns[0][2]
                #ax.scatter([x], [z], s=30, zorder=2, c="blue")
                plot_semantic_position(pos_rtns[0], pos_rtns[1], ax)
                i+=1
                #if i == 3: break

            ax.set_ylim(y_init)
            ax.set_xlim(x_init)
        else:
            # map
            for pos_rtns in classified_positions:
                x = pos_rtns[0][0]
                z = pos_rtns[0][2]
                colour = RoomType.colour_of_room(pos_rtns[2])
                ax.scatter([x], [z], s=30, zorder=2, c=colour)
                #plot_semantic_position(pos_rtns[0], pos_rtns[1], ax)

        plt.axis('off')
        plt.show()

    def display_semantic_map():
        classified_poses = prepare_classified_poses_for_processing()
        visualise_map(classified_poses, False)
        visualise_map(classified_poses, True)

        for p in sm.scene_description.getAllVisibleObjectsInThisRoom(ClassifierType.LLM, RoomType.BEDROOM):
            if "Dresser" in str(p["name"]):
                print(str(p["name"]) + " " + str(p["position"]) + " " + str(p["rotation"]))

display_semantic_map()
# Out:
# Dresser|7|1 {'x': 14.163481712341309, 'y': 0.0007619559764862061, 'z': 0.37396442890167236} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|7|1 {'x': 14.163481712341309, 'y': 0.0007619559764862061, 'z': 0.37396442890167236} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|7|1 {'x': 14.163481712341309, 'y': 0.0007619559764862061, 'z': 0.37396442890167236} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|7|1 {'x': 14.163481712341309, 'y': 0.0007619559764862061, 'z': 0.37396442890167236} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|7|1 {'x': 14.163481712341309, 'y': 0.0007619559764862061, 'z': 0.37396442890167236} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|7|1 {'x': 14.163481712341309, 'y': 0.0007619559764862061, 'z': 0.37396442890167236} {'x': -0.0, 'y': 0.0, 'z': 0.0}
# Dresser|8|1 {'x': 7.603726863861084, 'y': 0.0004146099090576172, 'z': 7.819602966308594} {'x': -0.0, 'y': 90.0, 'z': -0.0}
# Dresser|6|1 {'x': 8.115100860595703, 'y': 0.0006645917892456055, 'z': 2.150116443634033} {'x': -0.0, 'y': 0.0, 'z': 0.0}

# %%
room_points = sm.scene_description.get_all_points()

for rp in room_points:
    (current_xy, current_rot) = rp['point_pose'] # get current XY position
    print(rp['room_type_llm'].name + " : " + str(rp['visible_object_names']) + " : " + rp['room_type_gt'].name + " : " + rp['room_type_cvm'].name + " : " + rp['front_view_at_this_point'])
# Out:
# NOT_CLASSIFIED : {'Wall', 'DogBed', 'Pillow', 'Sofa', 'Floor'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/2.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Bowl', 'DiningTable', 'Wall', 'Plate', 'Statue', 'Floor', 'Doorway', 'Pen'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/3.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'DogBed', 'Floor', 'Doorway', 'DiningTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/8.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'DogBed', 'Pillow', 'Sofa', 'Floor', 'Doorway'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/7.png
# NOT_CLASSIFIED : {'Bowl', 'Wall', 'DogBed', 'Sofa', 'Drawer', 'Shelf', 'Floor', 'SideTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/6.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'DiningTable'} : BATHROOM : NOT_KNOWN : scene_pics/train_55/9.png
# NOT_CLASSIFIED : {'DishSponge', 'GarbageCan', 'Wall', 'SinkBasin', 'Painting', 'Faucet', 'Sink', 'SoapBottle', 'Drawer', 'Toilet', 'Dresser', 'Plunger'} : BATHROOM : BEDROOM : scene_pics/train_55/10.png
# NOT_CLASSIFIED : {'Painting', 'Doorway', 'Wall'} : BATHROOM : BEDROOM : scene_pics/train_55/12.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'DiningTable'} : BATHROOM : BATHROOM : scene_pics/train_55/13.png
# NOT_CLASSIFIED : {'Wall', 'Drawer', 'Doorway', 'Toilet'} : BATHROOM : BATHROOM : scene_pics/train_55/14.png
# NOT_CLASSIFIED : {'Painting', 'Wall', 'Plunger', 'GarbageCan'} : BATHROOM : BATHROOM : scene_pics/train_55/15.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Drawer', 'Sink', 'Toilet', 'Dresser'} : BATHROOM : BATHROOM : scene_pics/train_55/16.png
# NOT_CLASSIFIED : {'Chair', 'Pen', 'CellPhone', 'HousePlant', 'Floor', 'Box', 'Doorway', 'DiningTable', 'Watch'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/24.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Window', 'Floor', 'Doorway'} : LIVING_ROOM : BATHROOM : scene_pics/train_55/23.png
# NOT_CLASSIFIED : {'Painting', 'Window', 'Doorway', 'Wall'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/19.png
# NOT_CLASSIFIED : {'Doorway', 'DiningTable', 'Floor'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/20.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/22.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : KITCHEN : BATHROOM : scene_pics/train_55/25.png
# NOT_CLASSIFIED : {'Painting', 'Doorway', 'HousePlant', 'Wall'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/32.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'HousePlant', 'Floor'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/29.png
# NOT_CLASSIFIED : {'Wall', 'Doorway'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/28.png
# NOT_CLASSIFIED : {'Wall', 'Doorway'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/31.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/33.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : KITCHEN : KITCHEN : scene_pics/train_55/36.png
# NOT_CLASSIFIED : {'Chair', 'SprayBottle', 'Wall', 'CoffeeMachine', 'ButterKnife', 'Floor', 'Doorway', 'DiningTable'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/38.png
# NOT_CLASSIFIED : {'Chair', 'Book', 'ShelvingUnit', 'Wall', 'Shelf', 'Floor', 'CounterTop', 'Pot'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/37.png
# NOT_CLASSIFIED : {'Chair', 'Ladle', 'Bowl', 'SprayBottle', 'Toaster', 'CoffeeMachine', 'Statue', 'ButterKnife', 'Floor', 'CounterTop', 'Pot', 'DiningTable'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/39.png
# NOT_CLASSIFIED : {'Chair', 'Ladle', 'Bowl', 'SprayBottle', 'Toaster', 'CoffeeMachine', 'Statue', 'ButterKnife', 'DiningTable'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/40.png
# NOT_CLASSIFIED : {'Bowl', 'CellPhone', 'Wall', 'CoffeeTable', 'Pillow', 'BasketBall', 'Drawer', 'Statue', 'Bed', 'AlarmClock', 'Box', 'CD', 'Pen', 'Dresser'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/48.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Safe', 'Doorway', 'BaseballBat'} : BEDROOM : BATHROOM : scene_pics/train_55/42.png
# NOT_CLASSIFIED : {'Wall'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/45.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'CoffeeTable', 'BasketBall', 'Safe', 'Doorway', 'BaseballBat'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/44.png
# NOT_CLASSIFIED : {'Wall', 'CoffeeTable', 'Pillow', 'BasketBall', 'Bed', 'AlarmClock', 'Box', 'Doorway'} : BEDROOM : STORAGE : scene_pics/train_55/46.png
# NOT_CLASSIFIED : {'Bowl', 'CellPhone', 'Wall', 'Drawer', 'Statue', 'CD', 'Pen', 'Dresser'} : BEDROOM : BEDROOM : scene_pics/train_55/47.png
# NOT_CLASSIFIED : {'Wall', 'BasketBall', 'Drawer', 'Floor', 'Dresser', 'Mug'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/49.png
# NOT_CLASSIFIED : {'Wall'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/54.png
# NOT_CLASSIFIED : {'Laptop', 'Book', 'GarbageCan', 'Wall', 'Bed', 'BaseballBat'} : BEDROOM : BATHROOM : scene_pics/train_55/51.png
# NOT_CLASSIFIED : {'Wall', 'BasketBall', 'Drawer', 'Floor', 'Dresser', 'Mug'} : BEDROOM : BEDROOM : scene_pics/train_55/52.png
# NOT_CLASSIFIED : {'Wall', 'Bed', 'BaseballBat', 'Floor'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/56.png
# NOT_CLASSIFIED : {'Laptop', 'Book', 'GarbageCan', 'Pillow', 'Floor', 'Bed', 'CellPhone', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/55.png
# NOT_CLASSIFIED : {'TissueBox', 'CreditCard', 'Wall', 'Television', 'Window', 'KeyChain', 'Shelf', 'TVStand'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/57.png
# NOT_CLASSIFIED : {'TissueBox', 'Chair', 'CreditCard', 'Wall', 'Television', 'Window', 'KeyChain', 'Statue', 'Shelf', 'TVStand', 'Box', 'DiningTable'} : LIVING_ROOM : OFFICE : scene_pics/train_55/63.png
# NOT_CLASSIFIED : {'Chair', 'Pen', 'Wall', 'Window', 'Floor', 'DiningTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/59.png
# NOT_CLASSIFIED : {'Chair', 'Pen', 'CellPhone', 'Wall', 'Painting', 'KeyChain', 'Drawer', 'Statue', 'HousePlant', 'SideTable', 'Box', 'Doorway', 'DiningTable', 'Watch'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/61.png
# NOT_CLASSIFIED : {'Chair', 'Bowl', 'Wall', 'Drawer', 'SideTable', 'Doorway', 'DiningTable', 'Watch'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/62.png
# NOT_CLASSIFIED : {'Chair', 'Pen', 'Bowl', 'Drawer', 'Floor', 'SideTable', 'DiningTable'} : LIVING_ROOM : OFFICE : scene_pics/train_55/64.png
# NOT_CLASSIFIED : {'ArmChair', 'Window', 'Wall'} : LIVING_ROOM : NOT_KNOWN : scene_pics/train_55/70.png
# NOT_CLASSIFIED : {'Wall', 'Window', 'Floor'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/66.png
# NOT_CLASSIFIED : {'Chair', 'Floor'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/67.png
# NOT_CLASSIFIED : {'Wall', 'Window', 'Floor'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/72.png
# NOT_CLASSIFIED : {'GarbageCan', 'Wall', 'Painting', 'Doorway', 'Plunger'} : BATHROOM : BATHROOM : scene_pics/train_55/80.png
# NOT_CLASSIFIED : {'Candle', 'Wall', 'Painting', 'Drawer', 'SoapBar', 'Toilet', 'Dresser'} : BATHROOM : BATHROOM : scene_pics/train_55/74.png
# NOT_CLASSIFIED : {'DishSponge', 'GarbageCan', 'Wall', 'SinkBasin', 'Painting', 'Faucet', 'Sink', 'SoapBottle', 'Drawer', 'Floor', 'Dresser', 'Plunger'} : BATHROOM : NOT_KNOWN : scene_pics/train_55/75.png
# NOT_CLASSIFIED : {'DishSponge', 'GarbageCan', 'Wall', 'SinkBasin', 'Painting', 'Faucet', 'Sink', 'SoapBottle', 'Floor', 'Plunger'} : BATHROOM : BATHROOM : scene_pics/train_55/78.png
# NOT_CLASSIFIED : {'Candle', 'DishSponge', 'SinkBasin', 'Wall', 'Painting', 'Faucet', 'Sink', 'Drawer', 'SoapBar', 'SoapBottle', 'Floor', 'Toilet', 'Dresser'} : BATHROOM : BATHROOM : scene_pics/train_55/77.png
# NOT_CLASSIFIED : {'Wall', 'BasketBall', 'Drawer', 'HousePlant', 'Dresser', 'Mug'} : BEDROOM : BATHROOM : scene_pics/train_55/81.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Bed'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/82.png
# NOT_CLASSIFIED : {'GarbageCan', 'Wall', 'BasketBall', 'Drawer', 'Floor', 'Bed', 'Dresser', 'BaseballBat'} : BEDROOM : BATHROOM : scene_pics/train_55/83.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'HousePlant'} : BEDROOM : BEDROOM : scene_pics/train_55/86.png
# NOT_CLASSIFIED : {'Book', 'GarbageCan', 'Wall', 'Pillow', 'Bed', 'CellPhone', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/88.png
# NOT_CLASSIFIED : {'Book', 'GarbageCan', 'Wall', 'Pillow', 'Floor', 'Bed', 'CellPhone', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/87.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'DogBed', 'Pillow', 'Sofa'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/89.png
# NOT_CLASSIFIED : {'Wall', 'Television', 'Pillow', 'Sofa', 'Doorway'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/96.png
# NOT_CLASSIFIED : {'Wall', 'Doorway'} : LIVING_ROOM : NOT_KNOWN : scene_pics/train_55/91.png
# NOT_CLASSIFIED : {'Wall', 'DogBed', 'Floor'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/95.png
# NOT_CLASSIFIED : {'Wall'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/93.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'DogBed', 'Pillow', 'Sofa', 'Floor'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/94.png
# NOT_CLASSIFIED : {'Wall', 'BasketBall', 'Drawer', 'Dresser', 'Mug'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/97.png
# NOT_CLASSIFIED : {'Wall', 'BaseballBat', 'GarbageCan'} : BEDROOM : OFFICE : scene_pics/train_55/100.png
# NOT_CLASSIFIED : {'Wall', 'BasketBall', 'Drawer', 'Dresser'} : BEDROOM : STORAGE : scene_pics/train_55/99.png
# NOT_CLASSIFIED : {'Wall', 'BaseballBat', 'GarbageCan'} : BEDROOM : BEDROOM : scene_pics/train_55/101.png
# NOT_CLASSIFIED : {'Wall', 'Drawer', 'Floor', 'HousePlant', 'Dresser', 'Mug'} : BEDROOM : KITCHEN : scene_pics/train_55/104.png
# NOT_CLASSIFIED : {'Wall', 'Drawer', 'Dresser'} : BEDROOM : BEDROOM : scene_pics/train_55/103.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Drawer', 'Desk', 'Floor', 'Cabinet', 'Doorway'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/105.png
# NOT_CLASSIFIED : {'Wall', 'Floor', 'Doorway', 'HousePlant', 'BaseballBat'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/107.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Wall', 'Painting', 'Drawer', 'Desk', 'Cabinet', 'Doorway'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/108.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Pillow', 'Floor', 'Bed', 'CellPhone', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/109.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Pillow', 'Bed', 'CellPhone', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/110.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Bed', 'Floor', 'Doorway'} : BEDROOM : BATHROOM : scene_pics/train_55/111.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Painting', 'Drawer', 'Desk', 'Floor', 'Cabinet', 'Doorway'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/112.png
# NOT_CLASSIFIED : {'DeskLamp', 'Window', 'Desk', 'Wall'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/120.png
# NOT_CLASSIFIED : {'Painting', 'Doorway', 'Wall'} : BEDROOM : BEDROOM : scene_pics/train_55/116.png
# NOT_CLASSIFIED : {'Wall', 'Window'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/117.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Desk', 'Statue', 'Cabinet', 'Doorway'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/119.png
# NOT_CLASSIFIED : {'Book', 'Wall', 'Painting', 'Window', 'Pillow', 'Floor', 'Bed', 'Box', 'Doorway', 'HousePlant', 'FloorLamp', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/124.png
# NOT_CLASSIFIED : {'Book', 'Wall', 'Painting', 'Window', 'Pillow', 'BasketBall', 'Bed', 'Box', 'HousePlant'} : BEDROOM : BEDROOM : scene_pics/train_55/122.png
# NOT_CLASSIFIED : {'Wall', 'ArmChair', 'Floor', 'Bed', 'Doorway', 'FloorLamp', 'BaseballBat'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/126.png
# NOT_CLASSIFIED : {'Wall', 'Window', 'ArmChair', 'Floor', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/127.png
# NOT_CLASSIFIED : {'Wall', 'ArmChair', 'Floor', 'Doorway', 'FloorLamp', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/128.png
# NOT_CLASSIFIED : {'ArmChair', 'Doorway', 'Wall', 'Floor'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/129.png
# NOT_CLASSIFIED : {'Wall', 'Sofa', 'Television', 'Floor'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/132.png
# NOT_CLASSIFIED : {'Wall', 'Television', 'ArmChair', 'Sofa', 'Floor', 'Doorway'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/133.png
# NOT_CLASSIFIED : {'Wall', 'Doorway'} : LIVING_ROOM : NOT_KNOWN : scene_pics/train_55/134.png
# NOT_CLASSIFIED : {'Wall', 'Television', 'ArmChair', 'Floor', 'Doorway'} : LIVING_ROOM : NOT_KNOWN : scene_pics/train_55/136.png
# NOT_CLASSIFIED : {'Doorway', 'DogBed', 'Floor'} : KITCHEN : BEDROOM : scene_pics/train_55/137.png
# NOT_CLASSIFIED : {'Wall'} : KITCHEN : BEDROOM : scene_pics/train_55/142.png
# NOT_CLASSIFIED : {'Wall'} : KITCHEN : KITCHEN : scene_pics/train_55/139.png
# NOT_CLASSIFIED : {'Doorway'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/143.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Bowl', 'DiningTable', 'Plate', 'DogBed', 'Statue', 'Floor', 'Doorway', 'Pen'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/144.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'DogBed', 'Pillow', 'Sofa', 'DiningTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/145.png
# NOT_CLASSIFIED : {'Wall', 'SideTable', 'Doorway', 'Bowl'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/149.png
# NOT_CLASSIFIED : {'Wall', 'SideTable', 'Doorway', 'Bowl'} : LIVING_ROOM : KITCHEN : scene_pics/train_55/152.png
# NOT_CLASSIFIED : {'Wall', 'Sofa', 'Television', 'Floor'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/150.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Bowl', 'DiningTable', 'Wall', 'Plate', 'DogBed', 'Pen'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/151.png
# NOT_CLASSIFIED : {'Laptop', 'Book', 'GarbageCan', 'Wall', 'Painting', 'Pillow', 'Bed', 'CellPhone', 'BaseballBat'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/158.png
# NOT_CLASSIFIED : {'Laptop', 'Book', 'Wall', 'Painting', 'Pillow', 'Bed', 'CellPhone'} : BEDROOM : BEDROOM : scene_pics/train_55/160.png
# NOT_CLASSIFIED : {'Book', 'GarbageCan', 'Wall', 'Pillow', 'Floor', 'Bed', 'CellPhone', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/155.png
# NOT_CLASSIFIED : {'Wall', 'Bed'} : BEDROOM : BEDROOM : scene_pics/train_55/156.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'ArmChair', 'Floor', 'Doorway', 'HousePlant'} : KITCHEN : BATHROOM : scene_pics/train_55/161.png
# NOT_CLASSIFIED : {'Chair', 'Wall', 'Floor', 'Doorway', 'DiningTable'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/165.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/164.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Fridge', 'Floor', 'Doorway', 'HousePlant'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/166.png
# NOT_CLASSIFIED : {'Chair', 'Pen', 'Ladle', 'SprayBottle', 'Toaster', 'CoffeeMachine', 'Statue', 'PepperShaker', 'Floor', 'Tomato', 'ButterKnife', 'Bread', 'DiningTable'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/167.png
# NOT_CLASSIFIED : {'Chair', 'Pen', 'Ladle', 'SprayBottle', 'Wall', 'Fridge', 'Toaster', 'CoffeeMachine', 'Statue', 'PepperShaker', 'ButterKnife', 'Tomato', 'Bread', 'DiningTable'} : KITCHEN : KITCHEN : scene_pics/train_55/168.png
# NOT_CLASSIFIED : {'DeskLamp', 'Book', 'Wall', 'BasketBall', 'Drawer', 'Desk', 'Doorway'} : BEDROOM : OFFICE : scene_pics/train_55/169.png
# NOT_CLASSIFIED : {'Wall', 'BasketBall', 'Drawer', 'Bed', 'Doorway', 'Dresser'} : BEDROOM : BEDROOM : scene_pics/train_55/174.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'CoffeeTable'} : BEDROOM : OFFICE : scene_pics/train_55/172.png
# NOT_CLASSIFIED : {'Wall', 'CoffeeTable', 'Pillow', 'BasketBall', 'Drawer', 'Bed', 'AlarmClock', 'Box', 'Doorway', 'Dresser'} : BEDROOM : BEDROOM : scene_pics/train_55/173.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Drawer', 'Desk', 'Cabinet', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/175.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Drawer', 'Desk', 'Cabinet', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/176.png
# NOT_CLASSIFIED : {'Painting', 'Window', 'ArmChair', 'Wall'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/177.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Pen', 'Bowl', 'Wall', 'Painting', 'Plate', 'DogBed', 'Statue', 'Floor', 'Doorway', 'DiningTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/178.png
# NOT_CLASSIFIED : {'Painting', 'Window', 'ArmChair', 'Wall'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/179.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Bowl', 'DiningTable', 'Plate', 'DogBed', 'Statue', 'Floor', 'Pen'} : LIVING_ROOM : NOT_KNOWN : scene_pics/train_55/184.png
# NOT_CLASSIFIED : {'Wall', 'Chair', 'DiningTable', 'Floor'} : LIVING_ROOM : NOT_KNOWN : scene_pics/train_55/182.png
# NOT_CLASSIFIED : {'Wall', 'CoffeeTable', 'Floor', 'Box', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/188.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Window', 'Drawer', 'Desk', 'Statue', 'Cabinet', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/187.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Painting', 'Window', 'Drawer', 'Desk', 'Statue', 'Cabinet', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/191.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : BEDROOM : BEDROOM : scene_pics/train_55/190.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'CoffeeTable', 'BasketBall', 'Floor', 'Box', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/192.png
# NOT_CLASSIFIED : {'CounterTop', 'Floor'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/193.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/194.png
# NOT_CLASSIFIED : {'Painting', 'Doorway', 'Wall'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/195.png
# NOT_CLASSIFIED : {'Book', 'ShelvingUnit', 'Wall', 'Painting', 'Plate', 'Shelf', 'SaltShaker', 'CounterTop', 'Pot'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/198.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Floor'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/197.png
# NOT_CLASSIFIED : {'Book', 'ShelvingUnit', 'Wall', 'Painting', 'Plate', 'Shelf', 'SaltShaker', 'CounterTop', 'Pot'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/199.png
# NOT_CLASSIFIED : {'Book', 'ShelvingUnit', 'Wall', 'Painting', 'Shelf'} : KITCHEN : BEDROOM : scene_pics/train_55/200.png
# NOT_CLASSIFIED : {'Bowl', 'CellPhone', 'Wall', 'Drawer', 'Statue', 'Bed', 'CD', 'Pen', 'Dresser'} : BEDROOM : BEDROOM : scene_pics/train_55/201.png
# NOT_CLASSIFIED : {'Wall', 'CoffeeTable', 'Pillow', 'Floor', 'Bed', 'Box', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/202.png
# NOT_CLASSIFIED : {'Bowl', 'Wall', 'CoffeeTable', 'Pillow', 'Statue', 'Floor', 'Bed', 'AlarmClock', 'Dresser'} : BEDROOM : BEDROOM : scene_pics/train_55/203.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'BasketBall', 'Safe', 'Floor', 'Doorway', 'BaseballBat'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/205.png
# NOT_CLASSIFIED : {'Wall', 'CoffeeTable', 'Pillow', 'Floor', 'Bed', 'AlarmClock', 'Box'} : BEDROOM : BEDROOM : scene_pics/train_55/206.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'CoffeeTable', 'Safe', 'Floor', 'Doorway', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/207.png
# NOT_CLASSIFIED : {'Wall', 'CoffeeTable', 'Floor', 'Box', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/208.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Bowl', 'DiningTable', 'Plate', 'Statue', 'Floor', 'Pen'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/216.png
# NOT_CLASSIFIED : {'Bowl', 'Wall', 'DogBed', 'Drawer', 'Shelf', 'Floor', 'SideTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/212.png
# NOT_CLASSIFIED : {'Bowl', 'Wall', 'Painting', 'Window', 'Drawer', 'Shelf', 'SideTable', 'Doorway', 'DiningTable'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/211.png
# NOT_CLASSIFIED : {'Chair', 'DiningTable', 'CellPhone', 'KeyChain', 'Statue', 'HousePlant', 'Box', 'Pen', 'Watch'} : LIVING_ROOM : NOT_KNOWN : scene_pics/train_55/214.png
# NOT_CLASSIFIED : {'Chair', 'Pen', 'CellPhone', 'Wall', 'Painting', 'Window', 'KeyChain', 'Statue', 'HousePlant', 'SideTable', 'Box', 'Doorway', 'DiningTable', 'Watch'} : LIVING_ROOM : STORAGE : scene_pics/train_55/215.png
# NOT_CLASSIFIED : {'Chair', 'Vase', 'ShelvingUnit', 'Wall', 'Painting', 'Window', 'Lettuce', 'WineBottle', 'SaltShaker', 'Floor', 'ButterKnife', 'CounterTop', 'Pot', 'Mug'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/220.png
# NOT_CLASSIFIED : {'Chair', 'Ladle', 'Bowl', 'SprayBottle', 'Wall', 'Window', 'Toaster', 'CoffeeMachine', 'Statue', 'ButterKnife', 'Bread', 'DiningTable'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/218.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'ShelvingUnit'} : KITCHEN : BEDROOM : scene_pics/train_55/224.png
# NOT_CLASSIFIED : {'Book', 'ShelvingUnit', 'Wall', 'Shelf', 'Floor'} : KITCHEN : BEDROOM : scene_pics/train_55/221.png
# NOT_CLASSIFIED : {'Chair', 'Doorway', 'DiningTable', 'Floor'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/222.png
# NOT_CLASSIFIED : {'Chair', 'Ladle', 'Bowl', 'Wall', 'Window', 'Toaster', 'CounterTop', 'DiningTable'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/223.png
# NOT_CLASSIFIED : {'Wall', 'Television', 'ArmChair', 'Drawer', 'Doorway', 'Dresser', 'FloorLamp', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/225.png
# NOT_CLASSIFIED : {'Wall', 'ArmChair', 'Bed', 'Doorway', 'FloorLamp', 'BaseballBat'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/226.png
# NOT_CLASSIFIED : {'Wall', 'Window', 'ArmChair', 'Bed', 'Box', 'Doorway', 'FloorLamp', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/227.png
# NOT_CLASSIFIED : {'Wall', 'Window', 'Bed', 'Box', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/228.png
# NOT_CLASSIFIED : {'Wall', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/229.png
# NOT_CLASSIFIED : {'Bowl', 'Wall', 'Television', 'ArmChair', 'RemoteControl', 'Drawer', 'Dresser'} : BEDROOM : BATHROOM : scene_pics/train_55/231.png
# NOT_CLASSIFIED : {'Wall', 'Window', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/232.png
# NOT_CLASSIFIED : {'Wall', 'Bed', 'Floor', 'Doorway', 'CellPhone'} : BEDROOM : BEDROOM : scene_pics/train_55/234.png
# NOT_CLASSIFIED : {'DeskLamp', 'Chair', 'Book', 'Wall', 'Drawer', 'Desk', 'Statue', 'Cabinet', 'Doorway'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/235.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Bed', 'Floor', 'CellPhone'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/238.png
# NOT_CLASSIFIED : {'Wall', 'Doorway'} : BEDROOM : BEDROOM : scene_pics/train_55/239.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'Chair', 'Floor'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/240.png
# NOT_CLASSIFIED : {'Book', 'Wall', 'BasketBall', 'Bed', 'Box', 'Doorway', 'HousePlant'} : BEDROOM : BEDROOM : scene_pics/train_55/247.png
# NOT_CLASSIFIED : {'Wall', 'ArmChair', 'Doorway', 'FloorLamp', 'BaseballBat'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/246.png
# NOT_CLASSIFIED : {'Wall', 'Television', 'ArmChair', 'FloorLamp', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/245.png
# NOT_CLASSIFIED : {'Wall', 'Doorway', 'HousePlant', 'FloorLamp', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/248.png
# NOT_CLASSIFIED : {'Chair', 'SprayBottle', 'Wall', 'Toaster', 'Doorway', 'CoffeeMachine', 'Statue', 'PepperShaker', 'Floor', 'Tomato', 'ButterKnife', 'Bread', 'DiningTable'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/249.png
# NOT_CLASSIFIED : {'Chair', 'SprayBottle', 'Wall', 'Fridge', 'Toaster', 'CoffeeMachine', 'Statue', 'PepperShaker', 'Floor', 'Tomato', 'ButterKnife', 'Bread', 'DiningTable'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/250.png
# NOT_CLASSIFIED : {'Painting', 'Doorway', 'HousePlant', 'Wall'} : KITCHEN : BEDROOM : scene_pics/train_55/251.png
# NOT_CLASSIFIED : {'Painting', 'Fridge', 'HousePlant', 'Wall'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/252.png
# NOT_CLASSIFIED : {'Chair', 'Wall', 'Fridge', 'CoffeeMachine', 'PepperShaker', 'Tomato', 'Bread', 'DiningTable'} : KITCHEN : OFFICE : scene_pics/train_55/256.png
# NOT_CLASSIFIED : {'Wall', 'HousePlant'} : BEDROOM : OFFICE : scene_pics/train_55/264.png
# NOT_CLASSIFIED : {'Wall', 'BasketBall', 'Drawer', 'HousePlant', 'Dresser', 'Mug'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/262.png
# NOT_CLASSIFIED : {'Wall', 'Floor'} : BEDROOM : BATHROOM : scene_pics/train_55/260.png
# NOT_CLASSIFIED : {'Floor'} : BEDROOM : BEDROOM : scene_pics/train_55/263.png
# NOT_CLASSIFIED : {'Chair', 'Wall', 'Desk', 'Floor', 'Doorway', 'FloorLamp'} : BEDROOM : NOT_KNOWN : scene_pics/train_55/268.png
# NOT_CLASSIFIED : {'Book', 'Wall', 'Painting', 'Window', 'Pillow', 'BasketBall', 'Bed', 'Box'} : BEDROOM : BEDROOM : scene_pics/train_55/266.png
# NOT_CLASSIFIED : {'Wall', 'Window', 'ArmChair', 'Bed', 'Box', 'Doorway', 'FloorLamp', 'BaseballBat'} : BEDROOM : BEDROOM : scene_pics/train_55/269.png
# NOT_CLASSIFIED : {'Book', 'Wall', 'Painting', 'Pillow', 'BasketBall', 'Bed', 'HousePlant'} : BEDROOM : BEDROOM : scene_pics/train_55/270.png
# NOT_CLASSIFIED : {'Chair', 'Wall', 'Window', 'Desk', 'Floor', 'Doorway', 'HousePlant'} : BEDROOM : LIVING_ROOM : scene_pics/train_55/271.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Window', 'Pillow', 'Floor', 'Bed', 'HousePlant'} : BEDROOM : BEDROOM : scene_pics/train_55/272.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Bowl', 'Wall', 'Plate', 'DogBed', 'Floor', 'DiningTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/278.png
# NOT_CLASSIFIED : {'Wall', 'Sofa'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/280.png
# NOT_CLASSIFIED : {'Chair', 'Candle', 'Bowl', 'Wall', 'Painting', 'Plate', 'DogBed', 'Floor', 'Doorway', 'DiningTable'} : LIVING_ROOM : LIVING_ROOM : scene_pics/train_55/276.png
# NOT_CLASSIFIED : {'Wall', 'Painting', 'Plate', 'DogBed', 'Floor', 'Doorway', 'DiningTable'} : LIVING_ROOM : BEDROOM : scene_pics/train_55/279.png
# NOT_CLASSIFIED : {'Wall', 'Doorway'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/286.png
# NOT_CLASSIFIED : {'Book', 'ShelvingUnit', 'Wall', 'Painting', 'Shelf', 'Floor'} : KITCHEN : LIVING_ROOM : scene_pics/train_55/287.png
# NOT_CLASSIFIED : {'Wall'} : KITCHEN : NOT_KNOWN : scene_pics/train_55/285.png
# NOT_CLASSIFIED : {'Wall'} : KITCHEN : BEDROOM : scene_pics/train_55/288.png

# %%
from semantic_mapper import SemanticMapper
from llm_room_classifier import LLMType
from room_type import RoomType

sm = SemanticMapper("train_55", LLMType.LLAMA)
#img = sm.get_top_down_frame()
sm.display_semantic_map()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 8765.58it/s]
# Loading val: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8183.18it/s]
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8880.99it/s]
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# Loading : train[55]

# %%
from semantic_mapper import SemanticMapper
from cvm_room_classifier import CVMType
from classifier_fusion_type import ClassifierFusionType

sm = SemanticMapper("train_55", CVMType.CHAMELEON, "_full_prompt") # Chameleon full prompt
#img = sm.get_top_down_frame()
sm.display_semantic_map(ClassifierFusionType.NO_FUSION)
sm.display_semantic_map(ClassifierFusionType.LLM_THEN_CVM)
sm.display_semantic_map(ClassifierFusionType.CVM_THEN_LLM)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 7712.40it/s]
# Loading val: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 7916.95it/s]
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 7699.25it/s]
# Loaded : experiment_data/pkl_CHAMELEON_full_prompt/scene_descr_train_55.pkl scene
# Loaded : experiment_data/pkl_LLAMA/scene_descr_train_55.pkl scene
# Loading : train[55]

# %%
from semantic_mapper import SemanticMapper
from cvm_room_classifier import CVMType

sm = SemanticMapper("train_55", CVMType.MOONDREAM, "_full_prompt") # Moondream full prompt
#img = sm.get_top_down_frame()
sm.display_semantic_map()
# Out:
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 8703.90it/s]
# Loading val: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 9343.74it/s]
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8724.25it/s]
# Loaded : experiment_data/pkl_MOONDREAM_full_prompt/scene_descr_train_55.pkl scene
# Loading : train[55]

# %%
from semantic_mapper import SemanticMapper
from cvm_room_classifier import CVMType

sm = SemanticMapper("train_55", CVMType.MOONDREAM, "_one_word") # Moondream one word
#img = sm.get_top_down_frame()
sm.display_semantic_map()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 8366.77it/s]
# Loading val: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8276.64it/s]
# Loading test: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 8080.37it/s]
# Loaded : experiment_data/pkl_MOONDREAM_one_word/scene_descr_train_55.pkl scene
# Loading : train[55]
